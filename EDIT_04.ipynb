// %% [markdown]
// # Funkcije prvog reda, II. dio
// ### EDIT napredni tečaj - 4. Praktični/domaći rad
//
// U ovoj vježbi nastavljamo s metodama za rad s nizovima. Ponovit ćemo metodu `map`, te se upoznati s novim metodama `filter` i `reduce`.
//
// **Upute:**
// 1. Pročitaj zadatak.
// 2. Upiši svoj kod u ćeliju ispod zadatka.
// 3. Pokreni izvršavanje koda.

// %% [markdown]
// ---

// %% [markdown]
// ## Dio 1: Map (Ponavljanje)
// Metoda `map` kreira novi niz transformirajući svaki element originalnog niza.

// %% [markdown]
// ### Zadatak 1.
// Zadan je niz temperatura u Celzijusima. Koristeći `map`, konvertiraj ih u Fahrenheite i spremi u niz `tempF`.
// *Formula: F = C * 1.8 + 32*

// %%
const celzijusi = [0, 10, 20, 30];

// Ovdje napiši svoj kod


// Očekivani ispis: [32, 50, 68, 86]

// %% [markdown]
// ### Zadatak 2.
// Zadan je niz punih imena. Koristeći `map`, kreiraj novi niz koji sadrži samo inicijale svakog imena.
// *Pomoć: Možeš koristiti metode stringa kao što su .split() i pristup indeksima.*

// %%
const imena = ["Ivan Horvat", "Pero Perić", "Ana Anić"];

// Ovdje napiši svoj kod


// Očekivani ispis: ["I.H.", "P.P.", "A.A."]

// %% [markdown]
// ---

// %% [markdown]
// ## Dio 2: Filter
// Metoda `filter` kreira **novi niz** koji sadrži samo one elemente originalnog niza koji zadovoljavaju određeni uvjet (vraćaju `true`).

// %% [markdown]
// ### Zadatak 3.
// Iz niza brojeva izdvoji samo one koji su pozitivni (veći od 0).

// %%
const brojevi = [10, -5, 3, -2, 0, 15];

// Ovdje napiši svoj kod


// Očekivani ispis: [10, 3, 15]

// %% [markdown]
// ### Zadatak 4.
// Zadan je niz riječi koje predstavljaju imena datoteka. Koristeći `filter`, zadrži samo one datoteke koje imaju ekstenziju '.txt'.
//
// *HINT: koristiti ugrađenu metodu nad stringovima `endsWidth()`.*

// %%
const datoteke = ["doc1.txt", "slika.png", "tablica.xlsx", "skripta.txt", "prezentacija.pptx"];

// Ovdje napiši svoj kod


// Očekivani ispis: ["doc1.txt", "skripta.txt"]

// %% [markdown]
// ### Zadatak 5.
// Iz popisa zaposlenika filtrirati one koji rade u odjelu "IT", a njihova dob je između 25 i 40 godina.

// %%
const zaposlenici = [
    { ime: "Marko", odjel: "IT", dob: 30 },
    { ime: "Luka", odjel: "HR", dob: 35 },
    { ime: "Ivan", odjel: "IT", dob: 22 },
    { ime: "Mia", odjel: "IT", dob: 28 },
    { ime: "Ana", odjel: "Dizajn", dob: 40 },
    { ime: "Klara", odjel: "IT", dob: 45 }
];

// Ovdje napiši svoj kod



// Očekivani ispis: [{ ime: "Marko", odjel: "IT", dob: 30 }, { ime: "Mia", odjel: "IT", dob: 28 }]

// %% [markdown]
// ### Zadatak 6.
// Zadan je niz objekata koje predstavljaju knjige. Koristeći kombinaciju `filter` i `map`, kreiraj niz `procitaneKnjige` koji sadrži naslove svih onih knjiga koje je čitatelj pročitao.

// %%
const knjige = [
    { naslov: "1984", procitana: true },
    { naslov: "Harry Potter", procitana: false },
    { naslov: "Gospodar prstenova", procitana: true }
];

// Ovdje napiši svoj kod


// Očekivani ispis: ["1984", "Gospodar prstenova"]

// %% [markdown]
// ---

// %% [markdown]
// ## Dio 3: Reduce
// Metoda `reduce` "sažima" cijeli niz u jednu vrijednost (broj, string, objekt ili novi niz). Koristi *akumulator* koji pamti rezultat iz prethodne iteracije.

// %% [markdown]
// ### Zadatak 7.
// Koristeći `reduce`, prebrojati koliko u nizu ima neparnih brojeva.

// %%
const niz = [2, 3, 4, 5, 11, 22, 34];

// Ovdje napiši svoj kod


// Očekivani ispis: 3

// %% [markdown]
// ### Zadatak 8.
// Koristeći `reduce` napraviti niz bez duplikata.

// %%
const niz = [1, 2, 3, 3, 2, 4, 3, 5];

// Ovdje napiši svoj kod


// Očekivani ispis: [1, 2, 3, 4, 5]

// %% [markdown]
// ### Zadatak 9.
// Zadan je niz proizvoda u košarici. Svaki proizvod ima propertyje `cijena` i `kolicina`. Koristeći `reduce`, izračunaj ukupnu cijenu cijele košarice.

// %%
const proizvodi = [ 
     { naziv: "Laptop", cijena: 1000, kolicina: 1 }, 
     { naziv: "Šalica", cijena: 30, kolicina: 4 }, 
     { naziv: "Monitor", cijena: 200, kolicina: 2 } 
];

// Ovdje napiši svoj kod


// Očekivani ispis: 1520

// %% [markdown]
// ### Zadatak 10.
//
// Zadana je lista objekata koja predstavlja knjige. Svaka knjiga ima sljedeće propertyje:
//
// - naslov (string) - naslov knjige
//
// - rating (niz brojeva) - ocjene (1-5) koje su korisnici dali knjizi
//
// Iz liste treba filtrirati knjige čiji je prosječan rating veći ili jednak 4.5.
//
// *Ovaj zadatak je kombinacija `filter` i `reduce` metode.*

// %%
const knjige = [
    { naslov: "Veliki Gatsby", rating: [5, 4, 5, 4] },
    { naslov: "Mali princ", rating: [3, 4, 4, 5, 5] },
    { naslov: "1984", rating: [4, 5, 5] },
    { naslov: "Lovac u žitu", rating: [3, 4, 4] }
];

// Ovdje napiši svoj kod



// Očekivani ispis: 
// [
//    { naslov: "Veliki Gatsby", rating: [5, 4, 5, 4] },
//    { naslov: "1984", rating: [4, 5, 5] },
// ];
