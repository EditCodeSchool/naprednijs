// %% [markdown]
// <div style="pointer-events: none;">
//     <h1>Funkcije prvog reda, I. dio</h1>
//     <h3>EDIT napredni tečaj - 3. Praktični/domaći rad</h3>
//     <p>U ovoj vježbi prolazimo kroz najčešće metode za rad s nizovima: <code>forEach</code>, <code>map</code>, <code>some</code> i <code>find</code>.</p>
//     <p><strong>Upute:</strong></p>
//     <ol>
//         <li>Pročitaj zadatak.</li>
//         <li>Upiši svoj kod u ćeliju ispod zadatka.</li>
//         <li>Pokreni izvršavanje koda pristiskom na ikonu 'Play' koja se nalazi na alatnoj traci.</li>
//     </ol>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <hr>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <h2>Dio 1: forEach</h2>
//     <p>Metoda <code>forEach</code> izvršava određenu funkciju za svaki element niza. Ne vraća novi niz.</p>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 1.</h3>
//     <p>Zadan je niz brojeva <code>brojevi</code>. Koristeći <code>forEach</code>, program treba zbrojiti sve brojeve i spremiti rezultat u varijablu <code>suma</code>.</p>
// </div>

// %%
const brojevi = [10, 20, 30, 40];
let suma = 0;

// Ovdje napiši svoj kod s forEach:


// (Ne mijenjati red ispod, služi za provjeru)
console.log("Suma niza:", suma);

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 2.</h3>
//     <p>Napisati program koji, koristeći metodu <code>forEach</code>, za svako ime u nizu <code>imena</code> ispisuje rečenicu: "Pozdrav, [ime]!".</p>
// </div>

// %%
const imena = ["Ana", "Marko", "Ivan"];

// Ovdje napiši svoj kod:

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 3.</h3>
//     <p>Napisati program koji, koristeći metodu <code>forEach</code>, prolazi kroz niz <code>ulazniBrojevi</code>. Ako je broj paran, dodaje ga u novi niz <code>parniBrojevi</code>.</p>
// </div>

// %%
const ulazniBrojevi = [1, 2, 3, 4, 5, 6, 7, 8];
let parniBrojevi = [];

// Ovdje napiši svoj kod:


console.log("Niz parnih brojeva:", parniBrojevi);

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 4.</h3>
//     <p>Napisati program koji koristi <code>forEach</code> za kreiranje objekta gdje je ključ svaka riječ u nizu, a vrijednost je duljina te riječi.</p>
// </div>

// %%
const niz = ["hello", "world", "javascript"];
let obj = {}

// Ovdje napiši svoj kod:


// Očekivani ispis: {hello: 5, world: 5, javascript: 10}

// %% [markdown]
// <div style="pointer-events: none;">
//     <hr>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <h2>Dio 2: Map</h2>
//     <p>Metoda <code>map</code> kreira <strong>novi niz</strong> transformirajući svaki element originalnog niza.</p>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 5.</h3>
//     <p>Napisati program koji, koristeći metodu <code>map</code>, kreira novi niz <code>kvadrati</code> koji sadrži kvadrate brojeva iz niza <code>baza</code>.</p>
// </div>

// %%
const baza = [2, 3, 4, 5];

// Ovdje napiši svoj kod (koristi const kvadrati = ...):


// Očekivan ispis: [4, 9, 16, 25]

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 6.</h3>
//     <p>Napisati program koji za zadani niz riječi, koristeći metodu <code>map</code> dodaje prefiks "auto-" svakoj riječi.</p>
// </div>

// %%
const niz = ["matic", "pilot", "nom"];

// Ovdje napiši svoj kod


// Očekivan ispis: ["auto-matic", "auto-pilot", "auto-nom"]

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 7.</h3>
//     <p>Zadan je niz objekata <code>korisnici</code>. Koristeći <code>map</code>, program treba kreirati novi niz <code>samoImena</code> koji sadrži samo stringove s imenima korisnika.</p>
// </div>

// %%
const korisnici = [
    { id: 1, ime: "Ivo", dob: 30 },
    { id: 2, ime: "Ana", dob: 25 },
    { id: 3, ime: "Marko", dob: 20 }
];

// Ovdje napiši svoj kod


// Očekivan ispis: ["Ivo", "Ana", "Marko"]

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 8.</h3>
//     <p>Napisati program koji će za zadani niz proizvoda, gdje svaki proizvod ima naziv i cijenu izraženu u eurima, koristeći metodu <code>map</code>, dodati PDV od 25% na cijenu svakog proizvoda i vratiti novi niz proizvoda u kojem su sve cijene izražene u eurima s uključenim PDV-om.</p>
// </div>

// %%
const proizvodi = [{naziv: 'mlijeko', cijena: 3}, {naziv: 'kruh', cijena: 2}];

// Ovdje napiši svoj kod


// Očekivan ispis: [{naziv: 'mlijeko', cijena: 3.75}, {naziv: 'kruh', cijena: 2.5}]

// %% [markdown]
// <div style="pointer-events: none;">
//     <hr>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <h2>Dio 3: Some</h2>
//     <p>Metoda <code>some</code> provjerava zadovoljava li <strong>barem jedan</strong> element niza uvjet. Vraća <code>true</code> ili <code>false</code>.</p>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 9.</h3>
//     <p>Napisati program koji provjerava postoji li u nizu <code>godine</code> itko tko je maloljetan (mlađi od 18) i rezultat sprema u varijablu <code>imaMaloljetnih</code>.</p>
// </div>

// %%
const godine = [20, 45, 19, 17, 30];

// Ovdje napiši svoj kod


// Očekivani ispis: false

// %% [markdown]
// <div style="pointer-events: none;">
//     <hr>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <h2>Dio 4: Find</h2>
//     <p>Metoda <code>find</code> vraća <strong>prvi element</strong> u nizu koji zadovoljava uvjet. Ako ga ne nađe, vraća <code>undefined</code>.</p>
// </div>

// %% [markdown]
// <div style="pointer-events: none;">
//     <h3>Zadatak 10.</h3>
//     <p>U nizu objekata <code>auti</code>, program treba pronaći <strong>prvi</strong> automobil kojem je boja "crna" i spremiti cijeli objekt u varijablu <code>crniAuto</code>.</p>
// </div>

// %%
const auti = [
    { marka: "BMW", boja: "plava" },
    { marka: "Audi", boja: "crna" },
    { marka: "Mercedes", boja: "crna" },
    { marka: "VW", boja: "bijela" }
];

// Ovdje napiši svoj kod


// Očekivani ispis: { marka: "Audi", boja: "crna" }
